# %%
from _ROTOR import *
from _MISSION_PLANNER import *
from _HELICOPTER import *
import numpy as np
import matplotlib.pyplot as plt

# %%
main_rotor = rotor()
main_rotor.set_rotor(radius=5,
                     root_cut_out=0.5,
                     blades =3,
                     chord0=0.5,
                     chord_slope=(0.3-0.5)/(5-0.5), 
                     twist0=np.deg2rad(5),
                     twist_slope=np.deg2rad(2-3) / (4.5),
                     omega= 50)   ### approx 500RPM

tail_rotor = rotor()
tail_rotor.set_rotor(
    radius=1,
    root_cut_out=0.2,
    blades=4,
    chord0=0.18,                                  
    chord_slope=(0.08 - 0.18) / (1-0.2),    
    twist0=np.deg2rad(3),
    twist_slope=np.deg2rad(-3/0.8),                      
    omega=250.0     ### approz  2388RPM                           
)

# %%
heli = helicopter(main_rotor,tail_rotor,main_pos = np.array([-1,0,-2]),
                  tail_pos=np.array([-8,0,0]),lifting_surfaces=[],control_surfaces=[],
                  stabilizers=[],weight=6000)
vel = 50
drag = 2.14*vel**2
heli.find_trim(velocity=vel,alpha_tpp=np.deg2rad(3),Drag= 5000)
# Out:
# === Trim Results ===
#
# Theta0 (main):  -3.74°
# Theta1c:        11.33°
# Theta1s:        1.84°
# Theta0_tail:    -0.64°
#
# Forces (N): FX, FY, FZ = 35212.322866667135 1786.5384888982085 -60128.46751910417
# Moments (N·m): MX, MY, MZ = 201431.55075079342 773.348950496058 501.79915665156295
# c:\Users\Admin\Desktop\rotary\assignments\code_folder\Rotary_AE667\_HELICOPTER.py:137: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last five Jacobian evaluations.
#   sol = fsolve(trim_objective, x0)
# {'theta0': -0.06524069634020958,
#  'theta1c': 0.19776143299870316,
#  'theta1s': 0.032099133948899156,
#  'theta0_tail': -0.011112289478554187,
#  'forces': {'FX': 35212.322866667135,
#   'FY': 1786.5384888982085,
#   'FZ': -60128.46751910417,
#   'MX': 201431.55075079342,
#   'MY': 773.348950496058,
#   'MZ': 501.79915665156295}}

# %% [markdown]
# ### mission planner

# %%
"""
Simple Mission Planner Examples
"""
import numpy as np
from _ROTOR import rotor
from _HELICOPTER import helicopter
from _MISSION_PLANNER import MissionPlanner

# ==================== SETUP HELICOPTER ====================

main_rotor = rotor()
main_rotor.set_rotor(radius=5,
                     root_cut_out=0.5,
                     blades =3,
                     chord0=0.5,
                     chord_slope=(0.3-0.5)/(5-0.5), 
                     twist0=np.deg2rad(5),
                     twist_slope=np.deg2rad(2-3) / (4.5),
                     omega= 50)   ### approx 500RPM

tail_rotor = rotor()
tail_rotor.set_rotor(
    radius=1,
    root_cut_out=0.2,
    blades=4,
    chord0=0.18,                                  
    chord_slope=(0.08 - 0.18) / (1-0.2),    
    twist0=np.deg2rad(3),
    twist_slope=np.deg2rad(-3/0.8),                      
    omega=250.0     ### approz  2388RPM                           
)

heli = helicopter(main_rotor,tail_rotor,main_pos = np.array([-1,0,-2]),
                  tail_pos=np.array([-8,0,0]),lifting_surfaces=[],control_surfaces=[],
                  stabilizers=[],weight=6000)

# %%
# ==================== MISSION 1: Simple Patrol ====================
print("\n" + "*"*60)
print("MISSION 1: Simple Patrol")
print("█"*60)

mission1 = MissionPlanner(heli, engine_power_kw=2000, sfc=1.389e-4)
mission1.initialize(takeoff_weight=6000, fuel_weight=500, initial_altitude=0)

mission1_segments = [
    {'type': 'hover', 'duration_s': 120},
    {'type': 'climb', 'height_m': 1500, 'climb_rate': 5},
    {'type': 'forward', 'velocity': 50, 'distance_m': 80000},
    {'type': 'hover', 'duration_s': 300},
    {'type': 'forward', 'velocity': 50, 'distance_m': 80000},
]

mission1.execute_mission(mission1_segments)
# Out:
# ************************************************************
# MISSION 1: Simple Patrol
# ████████████████████████████████████████████████████████████
#
# Mission Start: Weight=6000.0kg, Fuel=500.0kg, Alt=0m
#
# ============================================================
# MISSION EXECUTION
# ============================================================
#
# --- Hover: 120s ---
#   Power: 259.9 kW
#   Fuel used: 4.33 kg, Remaining: 495.7 kg
#
# --- Climb: 1500m @ 5.0 m/s ---
#   New altitude: 1500 m
#   Power: 226.9 kW
#   Fuel used: 9.45 kg, Remaining: 486.2 kg
#
# --- Forward Flight: 80.0 km @ 50.0 m/s ---
# c:\Users\Admin\Desktop\rotary\assignments\code_folder\Rotary_AE667\_HELICOPTER.py:137: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last five Jacobian evaluations.
#   sol = fsolve(trim_objective, x0)
# === Trim Results ===
#
# Theta0 (main):  -5.70°
# Theta1c:        10.62°
# Theta1s:        2.42°
# Theta0_tail:    -0.65°
#
# Forces (N): FX, FY, FZ = 36577.88344408297 2184.850030284381 -6784.398790506875
# Moments (N·m): MX, MY, MZ = 202083.2769047172 1173.5683262440011 246.46731092861955
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 17
#       7 mission1.initialize(takeoff_weight=6000, fuel_weight=500, initial_altitude=0)
#       9 mission1_segments = [
#      10     {'type': 'hover', 'duration_s': 120},
#      11     {'type': 'climb', 'height_m': 1500, 'climb_rate': 5},
#    (...)
#      14     {'type': 'forward', 'velocity': 50, 'distance_m': 80000},
#      15 ]
# ---> 17 mission1.execute_mission(mission1_segments)
#
# File c:\Users\Admin\Desktop\rotary\assignments\code_folder\Rotary_AE667\_MISSION_PLANNER.py:349, in MissionPlanner.execute_mission(self, segments)
#     346     success = self.climb(seg['height_m'], seg['climb_rate'])
#     348 elif seg_type == 'forward':
# --> 349     success = self.forward_flight(
#     350         velocity=seg['velocity'],
#     351         distance_m=seg['distance_m'],
#     352         alpha_tpp=seg.get('alpha_tpp', 0.05),
#     353         drag_coeff=seg.get('drag_coeff', 2.14)
#     354     )
#     356 else:
#     357     print(f"Unknown segment type: {seg_type}")
#
# File c:\Users\Admin\Desktop\rotary\assignments\code_folder\Rotary_AE667\_MISSION_PLANNER.py:283, in MissionPlanner.forward_flight(self, velocity, distance_m, alpha_tpp, drag_coeff)
#     281 # === 1️⃣ Trim the helicopter ===
#     282 trim = self.helicopter.find_trim(velocity=velocity, alpha_tpp=alpha_tpp, Drag=drag)
# --> 283 theta0, theta1c, theta1s, theta0_tail = trim['controls']
#     285 print(f"  Trim: θ0={theta0:.4f}, θ1c={theta1c:.4f}, θ1s={theta1s:.4f}, θ_tail={theta0_tail:.4f}")
#     287 # === 2️⃣ Compute rotor loads at trim ===
#
# KeyError: 'controls'
